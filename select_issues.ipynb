# %%
import pandas as pd

# %%
proj = pd.read_csv('./issue_prjs.csv')
proj
# Out:
#                             _id         id                 name language  \
# 0      5e86ad7eca59557da3b66d7a       1334                rails     Ruby
# 1      5e86adf5ca59557da3b66d7b       1018                 node      NaN
# 2      5e86ae02ca59557da3b66d7c       4095        elasticsearch     Java
# 3      5e86af83ca59557da3b66d7d        340                netty     Java
# 4      5e86b009ca59557da3b66d7e       6815              vagrant     Ruby
# ...                         ...        ...                  ...      ...
# 52669  5e8b01928ada87d58aca4e19  137331451          http-client      PHP
# 52670  5e8b01928ada87d58aca4e1b  135592868  LeetCode-All-In-One      NaN
# 52671  5e8b01928ada87d58aca4e1d  120139836         c-aig-reader      C++
# 52672  5e8b01928ada87d58aca4e1f  137582086  Total-RP-3-Extended      Lua
# 52673  5e8b01928ada87d58aca4e21  137583004        Extended-mule      NaN
#
#        total  issues  pull_reqs  assigned   forked collected  ...  \
# ...

# %%
print(len(proj))
print(sum(proj.issues))
# Out:
# 52674
# 21579669

# %%
selected = proj.loc[(proj.issues >= 2000) & (proj.stars >= 1000) & (proj.forked >= 0)]
print(len(selected))
print(sum(selected.issues), sum(selected.issues) / 21579669 * 100)
# Out:
# 728
# 3539782 16.403319253877342

# %%
print(list(selected.name.values))
# Out:
# ['rails', 'node', 'elasticsearch', 'netty', 'vagrant', 'pdf.js', 'scikit-learn', 'matplotlib', 'core', 'jOOQ', 'symfony', 'devise', 'jQuery-File-Upload', 'spksrc', 'jshint', 'gitlabhq', 'brackets', 'CouchPotatoServer', 'rvm', 'zfs', 'kivy', 'julia', 'MinecraftForge', 'Reddit-Enhancement-Suite', 'three.js', 'composer', 'MonoGame', 'cdnjs', 'gaia', 'SignalR', 'diaspora', 'highcharts.com', 'requests', 'opencart', 'khan-exercises', 'OpenELEC.tv', 'ansible', 'woocommerce', 'sqlmap', 'Cinnamon', 'traccar', 'spree', 'zf2', 'ember.js', 'FreeRDP', 'openFrameworks', 'ipython', 'rails_admin', 'meteor', 'yii', 'openlayers', 'pandas', 'emscripten', 'gitextensions', 'django-rest-framework', 'phpunit', 'fish-shell', 'data', 'youtube-dl', 'jquery-mobile', 'cytoscape.js', 'sidekiq', 'h', 'qBittorrent', 'travis-ci', 'cesium', 'TrinityCore', 'pandoc', 'Font-Awesome', 'rubinius', 'NuGetGallery', 'headphones', 'yowsup', 'mapnik', 'salt', 'symfony-docs', 'linux', 'ace', 'supercollider', 'magento2', 'bitco
# ...
